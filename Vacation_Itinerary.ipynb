# %% [markdown]
# ## Deliverable 3. Create a Travel Itinerary Map.

# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps

# Import API key
from config import g_key

# Configure gmaps
gmaps.configure(api_key=g_key)

# %%
# 1. Read the WeatherPy_vacation.csv into a DataFrame.
vacation_df = pd.read_csv("Vacation_Search/WeatherPy_vacation.csv")
vacation_df.tail(15)
# Out:
#      City_ID         City Country  Max Temp Current Description      Lat  \
# 202      665       Contai      IN     79.03    scattered clouds  21.7786
# 203      675  Bandarbeyla      SO     78.24           clear sky   9.4942
# 204      677      Kassala      SD     76.55           clear sky  15.4510
# 205      678         Gizo      SB     82.00          light rain  -8.1030
# 206      679      Paciran      ID     77.72       broken clouds  -6.8767
# 207      680     Rach Gia      VN     80.60    scattered clouds  10.0167
# 208      686        Kochi      IN     77.00                mist   9.9399
# 209      690      Tagusao      PH     79.18       broken clouds   9.1924
# 210      691   Mahibadhoo      MV     82.65          few clouds   3.7833
# 211      698      Maumere      ID     79.02    scattered clouds  -8.6199
# 212      701     Belmonte      BR     77.00          few clouds -15.8631
# 213      707         Buin      CL     82.40           clear sky -33.7333
# ...

# %%
# 2. Using the template add the city name, the country code, the weather description and maximum temperature for the city.
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Current Description</dt><dd>{Current Description}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""

# 3a. Get the data from each row and add it to the formatting template and store the data in a list.
vacation_info = [info_box_template.format(**row) for index, row in vacation_df.iterrows()]

# 3b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = vacation_df[["Lat", "Lng"]]

# %%
# 4a. Add a marker layer for each city to the map.
locations = vacation_df[["Lat", "Lng"]]
max_temp = vacation_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp,dissipating=False,
             max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations, info_box_content=vacation_info)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)
# 4b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# From the map above pick 4 cities and create a vacation itinerary route to travel between the four cities. 
# 5. Create DataFrames for each city by filtering the 'vacation_df' using the loc method. 
# Hint: The starting and ending city should be the same city.

vacation_start = vacation_df.loc[lambda vacation_df: vacation_df.City == 'Ontario', :]
vacation_end = vacation_df.loc[lambda vacation_df: vacation_df.City == 'Ontario', :]
vacation_stop1 = vacation_df.loc[lambda vacation_df: vacation_df.City == 'Saint George', :]
vacation_stop2 = vacation_df.loc[lambda vacation_df: vacation_df.City == 'Jasper', :]
vacation_stop3 = vacation_df.loc[lambda vacation_df: vacation_df.City == 'San Patricio', :]

# %%
vacation_stop1
# Out:
#     City_ID          City Country  Max Temp Current Description      Lat  \
# 21       81  Saint George      US      84.0           clear sky  37.1041
#
#          Lng                   Hotel Name
# 21 -113.5841  Best Western Plus Abbey Inn

# %%
# 6. Get the latitude-longitude pairs as tuples from each city DataFrame using the to_numpy function and list indexing.

start = [tuple(r) for r in vacation_start.to_numpy().tolist()]
end = [tuple(r) for r in vacation_end.to_numpy().tolist()]
stop1 = [tuple(r) for r in vacation_stop1.to_numpy().tolist()]
stop2 = [tuple(r) for r in vacation_stop2.to_numpy().tolist()]
stop3 = [tuple(r) for r in vacation_stop3.to_numpy().tolist()]

# %%
start
# Out:
# [(636,
#   'Ontario',
#   'US',
#   80.01,
#   'broken clouds',
#   34.0633,
#   -117.6509,
#   'American Inn')]

# %%
# 7. Create a direction layer map using the start and end latitude-longitude pairs,
# and stop1, stop2, and stop3 as the waypoints. The travel_mode should be "DRIVING", "BICYCLING", or "WALKING".

#Define locations
Ontario = (34.0633, -117.6509)
Ontario = (34.0633, -117.6509)
stop1 = (37.1041, -113.5841)
stop2 = (37.2001, -94.3502)
stop3 = (28.017, -97.5169)

#Create the map
fig = gmaps.figure()
#create the layer
start2end = gmaps.directions_layer(Ontario, Ontario, waypoints=[stop1, stop2, stop3], travel_mode="DRIVING")
#Add the layer
fig.add_layer(start2end)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# 8. To create a marker layer map between the four cities.
#  Combine the four city DataFrames into one DataFrame using the concat() function.
itinerary_df = pd.concat([vacation_start, vacation_end, vacation_stop1, vacation_stop2, vacation_stop3], ignore_index=True)
itinerary_df
# Out:
#    City_ID          City Country  Max Temp Current Description      Lat  \
# 0      636       Ontario      US     80.01       broken clouds  34.0633
# 1      636       Ontario      US     80.01       broken clouds  34.0633
# 2       81  Saint George      US     84.00           clear sky  37.1041
# 3      661        Jasper      US     77.00           clear sky  37.2001
# 4      153  San Patricio      US     86.00           clear sky  28.0170
#
#         Lng                   Hotel Name
# 0 -117.6509                 American Inn
# 1 -117.6509                 American Inn
# 2 -113.5841  Best Western Plus Abbey Inn
# 3  -94.3502            Guest House Motel
# 4  -97.5169           Motel 6 Sinton, TX

# %%
# 9 Using the template add city name, the country code, the weather description and maximum temperature for the city. 
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Current Description</dt><dd>{Current Description}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""

# 10a Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in itinerary_df.iterrows()]

# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = itinerary_df[["Lat", "Lng"]]

# %%
# 11a. Add a marker layer for each city to the map.
from ipywidgets.embed import embed_minimal_html
locations = itinerary_df[["Lat", "Lng"]]
max_temp = itinerary_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp,dissipating=False,
             max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)

# 11b. Display the figure

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
